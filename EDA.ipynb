# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#import networkx as nx

# %%
coursera_courses_df = pd.read_csv('Data/Coursera_courses.csv')
coursera_courses_df.head(5)
# Out:
#                                                 name
# 0                                   Machine Learning  \
# 1                                  Indigenous Canada
# 2                          The Science of Well-Being
# 3                     Technical Support Fundamentals
# 4  Become a CBRS Certified Professional Installer...
#
#                  institution
# 0        Stanford University  \
# 1      University of Alberta
# 2            Yale University
# 3                     Google
# 4  Google - Spectrum Sharing
#
#                                           course_url
# 0    https://www.coursera.org/learn/machine-learning  \
# 1   https://www.coursera.org/learn/indigenous-canada
# 2  https://www.coursera.org/learn/the-science-of-...
# 3  https://www.coursera.org/learn/technical-suppo...
# 4  https://www.coursera.org/learn/google-cbrs-cpi...
#
#                         course_id
# 0                machine-learning
# 1               indigenous-canada
# ...

# %% [markdown]
#  **Seleccionemos el top 17 intituciones con más cursos en Coursera**

# %%
coursera_courses_df['institution'].value_counts()[0:17]
# Out:
# institution
# University of Pennsylvania                    43
# University of Michigan                        31
# Duke University                               24
# Google Cloud                                  22
# IBM                                           18
# Stanford University                           18
# University of Illinois at Urbana-Champaign    17
# University of Virginia                        17
# Yale University                               17
# DeepLearning.AI                               16
# University of California, Irvine              15
# Johns Hopkins University                      14
# University of California, Davis               13
# University of London                          12
# Universiteit Leiden                           11
# University of Colorado Boulder                10
# University of California San Diego            10
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.set(style="darkgrid")
sns.countplot(x='institution', data = coursera_courses_df, palette='Set2',order=coursera_courses_df['institution'].value_counts().index[0:17])
plt.title('Top 30 Instituciones con más Cursos Elaborados')
plt.xticks(rotation=90);

# %% [markdown]
# El top 3 Instituciones con más cursos son **University of Pennsylvania** con 43 cursos, **University of Michigan** con 31 y **Duke University** con 24 cursos.

# %%
coursera_reviews_df = pd.read_csv("Data/Coursera_reviews.csv")
coursera_reviews_df.head(5)
# Out:
#                                              reviews       reviewers
# 0  Pretty dry, but I was able to pass with just t...     By Robert S  \
# 1  would be a better experience if the video and ...  By Gabriel E R
# 2  Information was perfect! The program itself wa...      By Jacob D
# 3  A few grammatical mistakes on test made me do ...       By Dale B
# 4  Excellent course and the training provided was...       By Sean G
#
#    date_reviews  rating                 course_id
# 0  Feb 12, 2020       4  google-cbrs-cpi-training
# 1  Sep 28, 2020       4  google-cbrs-cpi-training
# 2  Apr 08, 2020       4  google-cbrs-cpi-training
# 3  Feb 24, 2020       4  google-cbrs-cpi-training
# 4  Jun 18, 2020       4  google-cbrs-cpi-training

# %%
coursera_reviews_df["reviewers"].value_counts()[0:17]
# Out:
# reviewers
# By Deleted A     1930
# By Muhammad A     229
# By Abhishek S     152
# By Michael S      152
# By David M        151
# By Michael M      135
# By David S        132
# By David B        130
# By Michael B      130
# By Aditya S       123
# By David C        122
# By Daniel M       117
# By Ankit S        108
# By Daniel S       108
# By Shubham S      108
# By Mohammad A     107
# By Muhammad S     106
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.set(style="darkgrid")
sns.countplot(x='reviewers', data = coursera_reviews_df, palette='Set2',order=coursera_reviews_df['reviewers'].value_counts().index[0:17])
plt.title('Top 17 Reviewers Con Más Participación')
plt.xticks(rotation=90);

# %% [markdown]
# Claramente se observa que **By Deleted A** es el reviewer con más participación en la evaluación de cursos

# %%
coursera_courses_reviews_df = pd.read_csv("Data/coursera_courses_reviews.csv")
coursera_courses_reviews_df.head(3)
# Out:
#                name          institution
# 0  Machine Learning  Stanford University  \
# 1  Machine Learning  Stanford University
# 2  Machine Learning  Stanford University
#
#                                         course_url         course_id
# 0  https://www.coursera.org/learn/machine-learning  machine-learning  \
# 1  https://www.coursera.org/learn/machine-learning  machine-learning
# 2  https://www.coursera.org/learn/machine-learning  machine-learning
#
#                                              reviews     reviewers
# 0  This is an extremely basic course. Machine lea...  By Deleted A  \
# 1  The course is ok but the certification procedu...    By Bruno C
# 2  I just started week 3 , I have to admit that I...       By Fadi
#
#    date_reviews  rating
# 0  Mar 18, 2017       1
# 1  Nov 09, 2015       1
# 2  Apr 15, 2019       1

# %% [markdown]
# ### Top 3 Cursos con más puntaje acumulado

# %%
df_aux=pd.DataFrame(coursera_courses_reviews_df[['name','rating']])
df_aux1 = pd.DataFrame(df_aux.groupby(by="name").sum())
df_aux1 = df_aux1.sort_values(by='rating',ascending=False)
df_aux1=df_aux1[0:15]

df_aux1
# Out:
#                                                     rating
# name
# Programming for Everybody (Getting Started with...   69791
# Machine Learning                                     60088
# Neural Networks and Deep Learning                    58648
# Technical Support Fundamentals                       57472
# Learning How to Learn: Powerful mental tools to...   56995
# Python Data Structures                               55395
# The Science of Well-Being                            40417
# Excel Skills for Business: Essentials                36061
# AI For Everyone                                      35786
# What is Data Science?                                34195
# Using Python to Access Web Data                      30571
# Improving Deep Neural Networks: Hyperparameter ...   29603
# First Step Korean                                    29185
# Google Cloud Platform Fundamentals: Core Infras...   27859
# The Data Scientist’s Toolbox                         26978

# %%
sns.barplot(x = df_aux1.index, y='rating', data=df_aux1)
plt.title('Top 15 Cursos con más puntaje Acumulado')
plt.xticks(rotation=90);

# %% [markdown]
# Los siguientes cursos son el top 3 con más puntaje acumulado:
#
# Programming for Everybody (Getting Started with Python): 69791 puntos
#
# Machine Learning: 60088 puntos
#
# Neural Networks and Deep Learning:	58648 puntos

# %% [markdown]
# # **EDX**

# %%
edx_df = pd.read_csv('Data/edx_courses.csv')
edx_df.head(3)
# Out:
#                                                title
# 0                                How to Learn Online  \
# 1  Programming for Everybody (Getting Started wit...
# 2            CS50's Introduction to Computer Science
#
#                                              summary n_enrolled
# 0  Learn essential strategies for successful onli...    124,980  \
# 1  This course is a "no prerequisite" introductio...    293,864
# 2  An introduction to the intellectual enterprise...  2,442,271
#
#                course_type                 institution
# 0  Self-paced on your time                         edX  \
# 1  Self-paced on your time  The University of Michigan
# 2  Self-paced on your time          Harvard University
#
#                                instructors         Level
# 0  Nina Huntemann-Robyn Belair-Ben Piscopo  Introductory  \
# 1                        Charles Severance  Introductory
# 2       David J. Malan-Doug Lloyd-Brian Yu  Introductory
#
# ...

# %%
edx_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975 entries, 0 to 974
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               975 non-null    object
#  1   summary             922 non-null    object
#  2   n_enrolled          855 non-null    object
#  3   course_type         975 non-null    object
#  4   institution         975 non-null    object
#  5   instructors         972 non-null    object
#  6   Level               975 non-null    object
#  7   subject             975 non-null    object
#  8   language            975 non-null    object
#  9   subtitles           972 non-null    object
#  10  course_effort       975 non-null    object
#  11  course_length       975 non-null    object
#  12  price               975 non-null    object
#  13  course_description  935 non-null    object
#  14  course_syllabus     414 non-null    object
# ...

# %%
edx_df['institution'].value_counts()[0:17]
# Out:
# institution
# Harvard University                       104
# Universitat Politècnica de Valencia       47
# Massachusetts Institute of Technology     41
# Delft University of Technology            30
# IBM                                       30
# Inter-American Development Bank           29
# The University of Queensland              26
# The University of Michigan                22
# Tecnológico de Monterrey                  21
# Columbia University                       20
# University of California, Berkeley        20
# Stanford University                       20
# Wageningen University & Research          18
# Universidad Autónoma de Madrid            17
# University of Adelaide                    17
# Universidades Anáhuac                     16
# SDG Academy                               16
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,3))
sns.set(style="darkgrid")
sns.countplot(x='institution', data = edx_df, palette='Set2',order=edx_df['institution'].value_counts().index[0:17]);
plt.title('Top 30 Instituciones')
plt.xticks(rotation=90);

# %% [markdown]
# Top 3 de las instituciones con más cursos:
#
# Harvard University con 104 cursos
#
# Universitat Politècnica de Valencia con 47
#
# Massachusetts Institute of Technology con 41

# %% [markdown]
# ### **Top de Temás con más cursos**

# %%
# Cantidad de cursos por tema
edx_df['subject'].value_counts()[0:17]
# Out:
# subject
# Computer Science                166
# Business & Management           164
# Data Analysis & Statistics       72
# Humanities                       64
# Engineering                      58
# Social Sciences                  51
# Economics & Finance              46
# Communication                    39
# Biology & Life Sciences          35
# Language                         34
# Math                             31
# Medicine                         31
# Education & Teacher Training     29
# History                          20
# Physics                          18
# Environmental Studies            16
# Art & Culture                    12
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,3))
sns.set(style="darkgrid")
sns.countplot(x='subject', data = edx_df, palette='Set2',order=edx_df['subject'].value_counts().index[0:17]);
plt.title('Top 17 Temas con más Cursos ')
plt.xticks(rotation=90);

# %% [markdown]
# Tenemos el siguiente top 3 temas (subject) con más cursos
#
# Computer Science: 166
#
# Business & Management: 164
#
# Data Analysis & Statistics: 72

# %% [markdown]
# ### **Cantidad de Curos por Nivel**

# %%
# Cantidad de cursos por tema
edx_nivel_df = edx_df['Level'].value_counts()
edx_nivel_df
# Out:
# Level
# Introductory    621
# Intermediate    267
# Advanced         87
# Name: count, dtype: int64

# %%
labels = edx_nivel_df.index
colors = sns.color_palette('bright')
plt.pie(edx_nivel_df, labels=labels,colors = colors, autopct = '%0.0f%%')
plt.title('Porcentaje de Cursos por Nivel')
plt.show()

# %% [markdown]
# Podemos ver que con 64% los cursos introductorios llevan la cabeza, con 27% los cursos intermedios y con solo el 9% los cursos avanzados.

# %% [markdown]
# ### **Cantidad de Cursos por tipo**

# %%
edx_tipo_df = edx_df['course_type'].value_counts()
edx_tipo_df
# Out:
# course_type
# Self-paced on your time                917
# Instructor-led on a course schedule     58
# Name: count, dtype: int64

# %%
labels = edx_tipo_df.index
colors = sns.color_palette('bright')
plt.pie(edx_tipo_df, labels=labels,colors = colors, autopct = '%0.0f%%')
plt.title('Porcentaje de Cursos por Nivel')
plt.show()

# %% [markdown]
# el 94% de los cursos son del tipo **Self-paced on your time** y solo el 6% es **Instructor-led on a course schedule**

# %% [markdown]
# # **UDEMY**

# %%
udemy_df = pd.read_csv('Data/udemy_courses.csv')
udemy_df.drop_duplicates(inplace=True)
udemy_df.head(3)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  Business Finance
# ...

# %%
udemy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   bool
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   object
#  11  subject              3672 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 347.8+ KB

# %% [markdown]
# ### **Cantidad por Tema(Subject)**

# %%
subject = pd.DataFrame(udemy_df['subject'].value_counts())
subject
# Out:
#                      subject
# Web Development         1199
# Business Finance        1191
# Musical Instruments      680
# Graphic Design           602

# %%
plt.figure(figsize=(12,5))
sns.set(style="darkgrid")
sns.countplot(x='subject', data = udemy_df, palette='Set2',order=udemy_df['subject'].value_counts().index[0:4]);
plt.title('Rating Movie vs Rating Tv Show');

# %% [markdown]
# Podemos ver que **Web Development** es la categoría con más cursos. En cuanto al nivel por categoría podemos observar que los cursos de nivel experto son considerablemente menos que los ofrecidos para todos los niveles y princiapiantes.

# %%
plt.figure(figsize=(12,5))
sns.set(style="darkgrid")
sns.countplot(x='subject', data = udemy_df, palette='Set2',order=udemy_df['subject'].value_counts().index[0:4],hue='level');
plt.title('Rating Movie vs Rating Tv Show');

# %% [markdown]
# ### **Cantidad de material elaborado según precio**

# %%
price_df = pd.DataFrame(udemy_df['price'].value_counts())
price_df[0:10]
# Out:
#      price
# 20     827
# 50     468
# 0      310
# 200    295
# 40     216
# 30     166
# 25     153
# 95     152
# 100    133
# 195    127

# %%
plt.figure(figsize=(12,5))
sns.set(style="darkgrid")
sns.countplot(x='price', data = udemy_df, palette='Set2',order=udemy_df['price'].value_counts().index[0:38]);
plt.title('Cantidad de Cursos Según Precio')
plt.xticks(rotation=90);

# %% [markdown]
# Se concluye que los cursos con valor de 20, 50, 0 y 200

# %%
udemy_df['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
WebDevelopment_df = udemy_df[udemy_df['subject']=='Web Development']
BusinessFinance_df = udemy_df[udemy_df['subject']=='Business Finance']
GraphicDesign_df = udemy_df[udemy_df['subject']=='Graphic Design']
MusicalInstruments_df = udemy_df[udemy_df['subject']=='Musical Instruments']

# %%
plt.figure(figsize=(12,5))
sns.set(style="darkgrid")
sns.countplot(x='level', data = WebDevelopment_df, palette='Set2',order=WebDevelopment_df['level'].value_counts().index[0:10]);
plt.title('Web Development')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(12,5))
sns.set(style="darkgrid")
sns.countplot(x='price', data = WebDevelopment_df, palette='Set2',order=WebDevelopment_df['price'].value_counts().index[0:10]);
plt.title('Web Development')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(12,5))
sns.set(style="darkgrid")
sns.countplot(x='price', data = BusinessFinance_df, palette='Set2',order=BusinessFinance_df['price'].value_counts().index[0:10]);
plt.title('Business Finance');

# %%
plt.figure(figsize=(12,5))
sns.set(style="darkgrid")
sns.countplot(x='price', data = GraphicDesign_df, palette='Set2',order=GraphicDesign_df['price'].value_counts().index[0:10]);
plt.title('Graphic Design');

# %%
plt.figure(figsize=(12,5))
sns.set(style="darkgrid")
sns.countplot(x='price', data = MusicalInstruments_df, palette='Set2',order=MusicalInstruments_df['price'].value_counts().index[0:10]);
plt.title('Musica Instruments');
